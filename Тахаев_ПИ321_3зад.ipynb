# %% [markdown]
# <a href="https://colab.research.google.com/github/Quja11/BAaS/blob/main/%D0%A2%D0%B0%D1%85%D0%B0%D0%B5%D0%B2_%D0%9F%D0%98321_3%D0%B7%D0%B0%D0%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Бизнес-аналитика и статистика 2022г Распределение\
# Гистограмма и кумулята\
# Тахаев А.Г. ПИ-321

# %%
import numpy as np

# %%
np.random.seed(19130600)
mu = 100
sigma = 10
N = 10000
x = np.random.normal(mu, sigma, N)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Гистограмма (столбиковая диаграмма частот)**

# %%
n = 10
plt.hist(x, n)
# Out:
# (array([  22.,  136.,  600., 1529., 2569., 2603., 1710.,  664.,  147.,
#           20.]), array([ 64.15120959,  71.24091462,  78.33061965,  85.42032467,
#          92.5100297 ,  99.59973473, 106.68943975, 113.77914478,
#         120.86884981, 127.95855483, 135.04825986]), <a list of 10 Patch objects>)

# %%
plt.figure(figsize = (12, 6))
plt.hist(x, bins = n, edgecolor = "black", linewidth = 2, facecolor = "white", density = True)
plt.title("Гистограмма нормального распределения")
plt.show()

# %%
from scipy.stats import norm
xx = np.linspace(60, 140, 100)
plt.plot(xx, norm.pdf(xx, loc = mu, scale = sigma))
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(x, bins=n, edgecolor='black', linewidth=2, facecolor='white', density=True, label='Гистограмма')
plt.plot(xx, norm.pdf(xx, loc=mu, scale=sigma), color="green", linewidth=2, label="Нормальное распределение")
plt.title("Нормальное распределение")
plt.legend()
plt.xlabel("Значение случайной величины")
plt.ylabel("Плотность вероятности")
plt.text(x=130, y=0.033, s=f"$\mu$ = {mu}\n$\sigma$ = {sigma}")
plt.show()

# %% [markdown]
# **Кумулята (график накопленных частот)**

# %%
plt.hist(x, bins=n, density=True, cumulative=True)
# Out:
# (array([0.0022, 0.0158, 0.0758, 0.2287, 0.4856, 0.7459, 0.9169, 0.9833,
#         0.998 , 1.    ]),
#  array([ 64.15120959,  71.24091462,  78.33061965,  85.42032467,
#          92.5100297 ,  99.59973473, 106.68943975, 113.77914478,
#         120.86884981, 127.95855483, 135.04825986]),
#  <a list of 10 Patch objects>)

# %%
(C_cum, x_cum, p_cum) = plt.hist(x, bins=n, density=True, cumulative=True)

# %%
x_cum.shape
# Out:
# (11,)

# %%
C_cum.shape
# Out:
# (10,)

# %%
plt.plot(x_cum[1:], C_cum)

# %%
plt.figure(figsize=(12, 6))
plt.plot(x_cum[1:], C_cum, color='black', linewidth=2, label='Кумулята', marker='o')
С = norm.cdf(xx, loc=mu, scale=sigma)
plt.plot(xx, С, color="green", linewidth=2, label="Нормальное распределение")
plt.title("Нормальное распределение")
plt.legend()
plt.xlabel("Значение случайной величины")
plt.ylabel("Вероятность (накопленные частоты)")
plt.text(x=63, y=0.8, s=f"$\mu$ = {mu}\n$\sigma$ = {sigma}")
plt.show()
